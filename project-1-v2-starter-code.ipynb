# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
# You are an analyst at a "scrappy" online gaming company that specializes in remakes of last year's fads.
#
# Your boss, who runs the product development team, is convinced that Pokemon Go's fatal flaw was that you had to actually move around outside. She has design mock-ups for a new game called Pokemon Stay: in this version players still need to move, but just from website to website. Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# She wants you to program a prototype version of the game, and analyze the planned content to help the team calibrate the design.

# %% [markdown]
# #### Package imports
#
# The pprint package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %% [markdown]
# ## Geoff Counihan

# %%
from pprint import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create the components for a player object by defining each of these variables. The dictionary and list variables should just be defined as empty; you can use any (correctly typed) values for the others.

# %%
player = {
    "player_id": 1,
    "player_name": "Zak",
    "time_played": float(),
    "player_pokemon": {},
    "gyms_visited": []
}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'amazon.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
gym_locations = [
    'reddit.com',
    'amazon.com',
    'twitter.com',
    'linkedin.com',
    'ebay.com',
    'netflix.com',
    'stackoverflow.com',
    'github.com',
    'quora.com',
    'medium.com',
    'kdnuggets.com',
    'google.com',
    'ibm.com',
    'airbnb.com',
    'cnn.com'
]

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print (or pretty print) the pokedex dictionary with the 3 pokemon.

# %%
pokedex = {
    1: {
        'name':'charmander',
        'type': 'fire',
        'hp': 140,
        'attack': 10,
        'defense': 20,
        'special_attack': 25,
        'special_defense': 10,
        'speed': 20
    },
    2: {
        'name':'squirtle',
        'type': 'water',
        'hp': 120,
        'attack': 15,
        'defense': 15,
        'special_attack': 35,
        'special_defense': 10,
        'speed': 25
    },
    3: {
        'name':'bulbasaur',
        'type': 'poison',
        'hp': 160,
        'attack': 5,
        'defense': 30,
        'special_attack': 25,
        'special_defense': 15,
        'speed': 10
    }
}

pprint(pokedex)
# Out:
# {1: {'attack': 10,
#      'defense': 20,
#      'hp': 140,
#      'name': 'charmander',
#      'special_attack': 25,
#      'special_defense': 10,
#      'speed': 20,
#      'type': 'fire'},
#  2: {'attack': 15,
#      'defense': 15,
#      'hp': 120,
#      'name': 'squirtle',
#      'special_attack': 35,
#      'special_defense': 10,
#      'speed': 25,
#      'type': 'water'},
#  3: {'attack': 5,
#      'defense': 30,
#      'hp': 160,
#      'name': 'bulbasaur',
#      'special_attack': 25,
#      'special_defense': 15,
#      'speed': 10,
#      'type': 'poison'}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1).
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %% [markdown]
# ## [] Initialize Players
# I thought i'd be adding a bunch of players over the course of the project so i figured making a function would be helpful.
# 1. added an if statement to disallow adding duplicate playerids
# 2. if playerid already exists, error message will print

# %%
players = {}

# %%
def add_player(player_id,player_name,time_played):
    player = {}
    player = {
    "player_id": player_id,
    "player_name": player_name,
    "time_played": float(time_played),
    "player_pokemon": {},
    "gyms_visited": []}
    if player_id not in players.keys():
        players[player_id] = player
    else:
        print("err: id already exists")
    return

# %% [markdown]
# ## [] Add Players

# %%
add_player(1,"Vay",15)
add_player(2,"Jay",25)
add_player(3,"Ray",25)
add_player(4,"May",45)
add_player(5,"Zay",25)
add_player(6,"Kay",5)
pprint(players)
# Out:
# err: id already exists
# {1: {'gyms_visited': [],
#      'player_id': 1,
#      'player_name': 'Vay',
#      'player_pokemon': {},
#      'time_played': 15.0},
#  2: {'gyms_visited': [],
#      'player_id': 2,
#      'player_name': 'Jay',
#      'player_pokemon': {},
#      'time_played': 25.0},
#  3: {'gyms_visited': [],
#      'player_id': 3,
#      'player_name': 'Ray',
#      'player_pokemon': {},
#      'time_played': 25.0},
#  4: {'gyms_visited': ['stackoverflow.com'],
#      'player_id': 4,
#      'player_name': 'Zay',
#      'player_pokemon': {1: {'attack': 10,
#                             'defense': 20,
#                             'hp': 140,
#                             'name': 'charmander',
#                             'special_attack': 25,
#                             'special_defense': 10,
#                             'speed': 20,
#                             'type': 'fire'}},
#      'time_played': 25.0},
#  5: {'gyms_visited': [],
#      'player_id': 5,
# ...

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'alcatraz'` and `'pacific_beach'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %% [markdown]
# ## [] Function for adding Gyms
# 1. checked if theyve already been to the gym being added
# 2. allows to put either a list of strings or just single gym as a string
# 3. doesn't let you add a gym to a player thats not in the players list
#
# Ended up making two functions:
# 1. gym_or_list parses the input if its a list or a string
# 2. gyms_visited determines if the player exists then calls the gym_or_list function

# %%
def gym_or_list(player_id,gyms):
    if type(gyms) == list:
        for gym in gyms:
            if gym not in players[player_id]['gyms_visited']:
                players[player_id]['gyms_visited'].append(gym)
            else:
                print("err: " + gym + " gym already visited")
    else:
        if gyms not in players[player_id]['gyms_visited']:
            players[player_id]['gyms_visited'].append(gyms)
        else:
            print("err: " + gyms + " gym already visited")
    return

def gyms_visited(player_id,gym):
    if player_id in players.keys():
        gym_or_list(player_id,gym)
#         if gym not in players[player_id]['gyms_visited']:
#             gym_or_list(player_id,gym)
#         else:
#             print("err: " + gym + " gym already visited")
    else:
        print("err: id: " + str(player_id) + " does not exist")
    return

# player2_gyms = ['alcatraz','pacific_beach']
#for gym in player2_gyms:
#    gym_visited(5,gym)

#gyms_visited(2,'alcatraz')

#gym_or_list(1,'boop')

#pprint(players)
# Out:
# err: id: 2 does not exist

# %% [markdown]
# ## [] Add gyms to players
# I did not add alcatraz or pacific beach because when checking later if players went to certain gyms they're not in my list above, but did add numerous other gyms on the list

# %%
pprint(gym_locations)
gyms_visited(1,'airbnb.com')
gyms_visited(3,'stackoverflow.com')
gyms_visited(3,'quora.com')
gyms_visited(2,'cnn.com')
gyms_visited(4,'stackoverflow.com')
gyms_visited(1,'medium.com')
gyms_visited(5,'stackoverflow.com')
gyms_visited(5,'github.com')
# Out:
# ['reddit.com',
#  'amazon.com',
#  'twitter.com',
#  'linkedin.com',
#  'ebay.com',
#  'netflix.com',
#  'stackoverflow.com',
#  'github.com',
#  'quora.com',
#  'medium.com',
#  'kdnuggets.com',
#  'google.com',
#  'ibm.com',
#  'airbnb.com',
#  'cnn.com']
# err: stackoverflow.com gym already visited

# %% [markdown]
# ## [] Clear gyms if needed

# %%
#clear gyms if playing around
#players[3]['gyms_visited'] = []

pprint(players)
# Out:
# {1: {'gyms_visited': ['airbnb.com', 'medium.com'],
#      'player_id': 1,
#      'player_name': 'Vay',
#      'player_pokemon': {},
#      'time_played': 15.0},
#  2: {'gyms_visited': ['cnn.com'],
#      'player_id': 2,
#      'player_name': 'Jay',
#      'player_pokemon': {},
#      'time_played': 25.0},
#  3: {'gyms_visited': ['stackoverflow.com', 'quora.com'],
#      'player_id': 3,
#      'player_name': 'Ray',
#      'player_pokemon': {},
#      'time_played': 25.0},
#  4: {'gyms_visited': ['stackoverflow.com'],
#      'player_id': 4,
#      'player_name': 'Zay',
#      'player_pokemon': {1: {'attack': 10,
#                             'defense': 20,
#                             'hp': 140,
#                             'name': 'charmander',
#                             'special_attack': 25,
#                             'special_defense': 10,
#                             'speed': 20,
#                             'type': 'fire'}},
#      'time_played': 25.0},
# ...

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %% [markdown]
# ## [] Add pokemon to players in the game
# Again, I felt like creating a function would be fun to do
#
# Added some smart functionality:
# 1. checks if player already has that pokemonid in caught list

# %%
def assign_pokemon(player_id,pokemon_id):
    pokemon = {}
    pokemon[pokemon_id] = pokedex[pokemon_id]
    #pprint(pokemon.keys())
    #pprint(players[player_id]['player_pokemon'].keys())
    if pokemon.keys()[0] not in players[player_id]['player_pokemon'].keys():
        players[player_id]['player_pokemon'][pokemon_id] = pokemon[pokemon_id]
    else:
        print("err: pokemon already caught")
    return

# %% [markdown]
# ## [] Use function.. my kernel failed so these are just randomly added pokemon at the moment
# Unfortunately this only pulls from the original list as opposed to the new one below

# %%
assign_pokemon(1,1)
assign_pokemon(1,2)
assign_pokemon(1,3)
assign_pokemon(2,1)
assign_pokemon(4,2)
assign_pokemon(5,1)
assign_pokemon(6,3)
assign_pokemon(6,1)
pprint(players)
# Out:
# err: pokemon already caught
# {1: {'gyms_visited': ['airbnb.com', 'medium.com'],
#      'player_id': 1,
#      'player_name': 'Vay',
#      'player_pokemon': {1: {'attack': 10,
#                             'defense': 20,
#                             'hp': 140,
#                             'name': 'charmander',
#                             'special_attack': 25,
#                             'special_defense': 10,
#                             'speed': 20,
#                             'type': 'fire'},
#                         2: {'attack': 15,
#                             'defense': 15,
#                             'hp': 120,
#                             'name': 'squirtle',
#                             'special_attack': 35,
#                             'special_defense': 10,
#                             'speed': 25,
#                             'type': 'water'},
#                         3: {'attack': 5,
#                             'defense': 30,
# ...

# %% [markdown]
# ## [] Remove pokemon if needed

# %%
#empty pokemon
#players[1]['player_pokemon'] = {}

# %% [markdown]
# ## 6. What gyms have players visited?
#
# ---
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.1
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %% [markdown]
# ## [] Count gyms in list
# 1. cycle through players
# 2. cycle through gyms in their gym lists
# 3. if that gym is in the master gym list then print

# %%
# for gym in gym_locations:
#     print(gym)
n = 0
for player_id in players:
    for players_gyms in players[player_id]['gyms_visited']:
        #pprint(players_gyms)
        #pprint(gym_locations)
        n += 1
        if players_gyms in gym_locations:
            print("player " + str(player_id) + " has visited " + str(players_gyms))
print("it ran " + str(n) + " times")
# Out:
# player 1 has visited airbnb.com
# player 1 has visited medium.com
# player 2 has visited cnn.com
# player 3 has visited stackoverflow.com
# player 3 has visited quora.com
# player 4 has visited stackoverflow.com
# player 5 has visited stackoverflow.com
# player 5 has visited github.com
# it ran 8 times

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.2
#
# How many times did that loop run? If you have N gyms and also N players, how many times would it run as a function of N?
#
# Can you think of a more efficient way to accomplish the same thing?
#
# (You can write your answer as Markdown text.)

# %% [markdown]
# ## [] Answer
# seems like its only running the number of gyms are in all the players gyms lists. I expected it to run gym x players amount of times, I'm not sure how to make it more efficient because you have to loop the player to print the player in the output, and you have to loop through their gyms to make sure they aren't in the gym_locations list

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %% [markdown]
# ## [] Calculate power
# 1. only uses attack, defense, specialattack, and specialdefense values of their pokemon
# 2. runs through each of their pokemon and sums the total

# %%
# pprint(pokedex[pokemon_id]['attack'])
# pprint(pokedex[pokemon_id]['defense'])
# pprint(pokedex[pokemon_id]['special_attack'])
# pprint(pokedex[pokemon_id]['special_defense'])

def player_power(players,pokedex,player_id):
    player_power = 0
    for key in players[player_id]['player_pokemon'].keys():
        player_power += pokedex[key]['attack']
        player_power += pokedex[key]['defense']
        player_power += pokedex[key]['special_attack']
        player_power += pokedex[key]['special_defense']
    print(players[player_id]['player_name'] + "'s power is " + str(player_power))
    return

player_power(players,pokedex,1)
# Out:
# Vay's power is 215

# %% [markdown]
# ## [] Run it through for all players to get a good idea whos leading the pack

# %%
for i in players.keys():
    player_power(players,pokedex,i)
# Out:
# Vay's power is 215
# Jay's power is 65
# Ray's power is 0
# Zay's power is 140
# Zay's power is 65
# Kay's power is 140

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# While you were putting together the prototype code, your colleagues were preparing a dataset of Pokemon and their attributes. (This was a rush job, so they may have picked some crazy values for some...)
#
# The code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %% [markdown]
# ## [] Used a bunch of ridiculous manuvers here
# 1. tried to find previous lessons that went though loading data
# 2. found a loop that made everything in the list a float if possible
# 3. still doesn't look very good but seems to have worked

# %%
# Code to read in pokedex info
raw_pd = ''
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()
    
# the pokedex string is assigned to the raw_pd variable

# %%
lines_pd = raw_pd.split('\n')

# %%
list_lines_pd = []
for line in lines_pd:
    list_lines_pd.append(line.split(','))
#pprint(list_lines_pd[0:3])

# %%
import string
a = list_lines_pd[1][0]
print(a[1:-1])
# Out:
# 001

# %%
str_list = []
for line in list_lines_pd:
    new_line = []
    for item in line:
        new_item = item[1:-1]
        new_line.append(new_item)
    str_list.append(new_line)
    
#pprint(str_list)

# %%
float_data = []
for line in str_list:
    float_line = []
    for item in line:
        try:
            float_line.append(float(item))
        except:
            if item == "":
                float_line.append(-1)
            elif item == " ":
                float_line.append(-1)
            else:
                float_line.append(item)
    float_data.append(float_line)
    
pprint(float_data)
# Out:
# [['PokedexNumber',
#   'Name',
#   'Type',
#   'Total',
#   'HP',
#   'Attack',
#   'Defense',
#   'SpecialAttack',
#   'SpecialDefense',
#   'Speed'],
#  [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0],
#  [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0],
#  [3.0, 'Venusaur', 'GrassPoison', 525.0, 80.0, 82.0, 83.0, 100.0, 100.0, 80.0],
#  [3.0,
#   'VenusaurMega Venusaur',
#   'GrassPoison',
#   625.0,
#   80.0,
#   100.0,
#   123.0,
#   122.0,
#   120.0,
#   80.0],
#  [4.0, 'Charmander', 'Fire', 309.0, 39.0, 52.0, 43.0, 60.0, 50.0, 65.0],
#  [5.0, 'Charmeleon', 'Fire', 405.0, 58.0, 64.0, 58.0, 80.0, 65.0, 80.0],
#  [6.0, 'Charizard', 'FireFlying', 534.0, 78.0, 84.0, 78.0, 109.0, 85.0, 100.0],
#  [6.0,
#   'CharizardMega Charizard X',
#   'FireDragon',
#   634.0,
#   78.0,
#   130.0,
#   111.0,
#   130.0,
#   85.0,
#   100.0],
#  [6.0,
#   'CharizardMega Charizard Y',
#   'FireFlying',
#   634.0,
#   78.0,
#   104.0,
#   78.0,
# ...

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %% [markdown]
# ## [] Skipped

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %% [markdown]
# ## [] Tried this for a a long time, ended up finding a much better solution in 1 line of code
# 1. originally tried to loop through the list I made above and add new key values for each line
# 2. couldn't figure out how to loop through while also equating the new single pokemon dict with a key val in the new pokedex dict
# 3. ended up taking the pandas approach, took the df and put it on its side with transpose
# 4. set the PokedexNumber as the index for the dictionary
# 5. and used the to_dict function which sets the index to the key and uses the columns and values as the rest
#
# *realized that there are multiple pokemon under certain pokedexnumbers like charzard and megacharzard. since there is no level value to differentiate these i decided to overwrite the value. a better approach would be to add both under that pokemonnumber

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('pokedex_basic.csv')
df['Speed'].unique()

def recreate_pokedex(df):
    new_pokedex = df.set_index('PokedexNumber').T.to_dict()
    return new_pokedex
        
new_pokedex = recreate_pokedex(df)
new_pokedex[6]
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/pandas/core/frame.py:882: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "columns will be omitted.", UserWarning)
# {'Attack': 104,
#  'Defense': 78,
#  'HP': 78,
#  'Name': 'CharizardMega Charizard Y',
#  'SpecialAttack': 159,
#  'SpecialDefense': 115,
#  'Speed': 100,
#  'Total': 634,
#  'Type': 'FireFlying'}

# %%
# line = float_data[2]
# new_pokedex = {}
# pokemon = {
#     line[0]: {
#         'name': line[1],
#         'type': line[2],
#         'hp': line[4],
#         'attack': line[5],
#         'defense': line[6],
#         'special_attack': line[7],
#         'special_defense': line[8],
#         'speed': line[9]
#     }}
# for i in range(len(df)):
#     print(df.loc[i,['PokedexNumber']])

# %%
#for example in the new pokedex PokedexNumber 6 is three levels of the same pokemon. Since there is no level indicator
#it makes sense for this exercise just to keep the last one
df.iloc[0:10,:]
# Out:
#    PokedexNumber                       Name         Type  Total  HP  Attack  \
# 0              1                  Bulbasaur  GrassPoison    318  45      49
# 1              2                    Ivysaur  GrassPoison    405  60      62
# 2              3                   Venusaur  GrassPoison    525  80      82
# 3              3      VenusaurMega Venusaur  GrassPoison    625  80     100
# 4              4                 Charmander         Fire    309  39      52
# 5              5                 Charmeleon         Fire    405  58      64
# 6              6                  Charizard   FireFlying    534  78      84
# 7              6  CharizardMega Charizard X   FireDragon    634  78     130
# 8              6  CharizardMega Charizard Y   FireFlying    634  78     104
# 9              7                   Squirtle        Water    314  44      48
#
#    Defense  SpecialAttack  SpecialDefense  Speed
# 0       49             65              65     45
# ...

# %%
#could not figure out how to do it this way
def recreate_pokedex(b):
    return

# new_pokedex = {}

# for line in float_data:
#     new_pokemon = {
#         line[0]: {
#             'name': line[1],
#             'type': line[2],
#             'hp': line[4],
#             'attack': line[5],
#             'defense': line[6],
#             'special_attack': line[7],
#             'special_defense': line[8],
#             'speed': line[9]
#         }}
#     pprint(new_pokemon)
    
#pprint(float_data[0:2])
#print(float_data[0:2])

# %% [markdown]
# <img src="http://i.imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# #
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %% [markdown]
# ## [] Filter Pokedex based on vals
# 1. run through every pokemon in the list and then look at the filter options
# 2. if the filter options are "met" add 1 to the counter
# 3. because the type filter can technically evaluate > or < had to skip it
# 4. then needed to take the length of the filter dictionary -1 meaning that all the values are true
# 5. use that with an if statement to get the right pokemon type too
# 6. add it to the new filterdex

# %%
filt = {
    'Attack':   80,
    'Defense':  60,
    'Type':     'Fire',
    'SpecialAttack': 50,
    'Speed': 100
}

# print(filt)

# %%
def filtered_pokedex(new_pokedex,filter_options):
    filterdex = []
    #del filter_options['Type'] <-- doesn't work because its needed for the type reference
    for i in range(len(new_pokedex)):
        c = 0
        for f in filter_options.keys():
            if f != 'Type':
                if new_pokedex[i+1][f] >= filter_options[f]:
                    c += 1
        if c == (len(filter_options.keys())-1) and new_pokedex[i+1]['Type'] == filter_options['Type']:
            filterdex.append(new_pokedex[i+1])
    return filterdex
       
#f = filter_options.keys()
#print(filt.keys())
#filt['Type']
#pprint(filterdex)
#new_pokedex[1]['Type'] >= filter_options['Type']

filtered_pokedex(new_pokedex,filt)
# Out:
# [{'Attack': 100,
#   'Defense': 70,
#   'HP': 65,
#   'Name': 'Rapidash',
#   'SpecialAttack': 80,
#   'SpecialDefense': 80,
#   'Speed': 105,
#   'Total': 500,
#   'Type': 'Fire'},
#  {'Attack': 84,
#   'Defense': 78,
#   'HP': 78,
#   'Name': 'Typhlosion',
#   'SpecialAttack': 109,
#   'SpecialDefense': 85,
#   'Speed': 100,
#   'Total': 534,
#   'Type': 'Fire'},
#  {'Attack': 115,
#   'Defense': 85,
#   'HP': 115,
#   'Name': 'Entei',
#   'SpecialAttack': 90,
#   'SpecialDefense': 75,
#   'Speed': 100,
#   'Total': 580,
#   'Type': 'Fire'},
#  {'Attack': 98,
#   'Defense': 63,
#   'HP': 75,
#   'Name': 'Simisear',
#   'SpecialAttack': 98,
#   'SpecialDefense': 63,
#   'Speed': 101,
#   'Total': 498,
#   'Type': 'Fire'}]

# %% [markdown]
# ## 9. Descriptive statistics on the prototype pokedex
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.1
#
# What is the population mean and standard deviation of the "Total" attribute for all characters in the Pokedex?

# %% [markdown]
# ## [] Looks similar to a binomial distribution

# %%
print(str(df['Total'].mean()) + ' mean')
print(str(df['Total'].std()) + ' std')

df['Total'].hist(bins=20)
# Out:
# 435.1275 mean
# 120.037066631 std

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.2
#
# The game is no fun if the characters are wildly unbalanced! Are any characters "overpowered", which we'll define as having a "Total" more than three standard deviations from the population mean?

# %%
mean = df['Total'].mean()
std = df['Total'].std()
df[df['Total'] > 3*std + mean]
#yup, this guy.. Mewtwo - I remember him from supersmash bros.. he wasn't that good they mustev balanced it
#with a difficult conrtols or learning curve or something
# Out:
#      PokedexNumber                 Name             Type  Total   HP  Attack  \
# 163            150  MewtwoMega Mewtwo X  PsychicFighting    800  126     190
#
#      Defense  SpecialAttack  SpecialDefense  Speed
# 163      100            154             100    130

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Calibrate the frequency of Pokemon
#
# The design team wants you to make the powerful Pokemon rare, and the weaklings more common. How would you set the probability $p_i$ of finding Pokemon *i* each time a player visits a gym?
#
# Write a function that takes in a Pokedex number and returns a value $p_i$ for that character.
#
# Hint: there are many ways you could do this. What do _you_ think makes sense? Start with simplifying assumptions: for example, you could assume that the probabilities of encountering any two Pokemon on one visit to a gym are independent of each other.

# %% [markdown]
# ## [] List Pokemon from weakest to strongest by total

# %%
weak_to_strong = list(df.sort_values('Total')['Name'])
# Out:
# ['Sunkern',
#  'Azurill',
#  'Kricketot',
#  'Wurmple',
#  'Weedle',
#  'Caterpie',
#  'Ralts',
#  'Scatterbug',
#  'Magikarp',
#  'Feebas',
#  'Cascoon',
#  'Pichu',
#  'Kakuna',
#  'Metapod',
#  'Silcoon',
#  'Wooper',
#  'Tyrogue',
#  'Igglybuff',
#  'Spewpa',
#  'Sentret',
#  'Cleffa',
#  'Poochyena',
#  'Happiny',
#  'Seedot',
#  'Lotad',
#  'Burmy',
#  'Shedinja',
#  'Bunnelby',
#  'Makuhita',
#  'Zigzagoon',
#  'Whismur',
#  'Combee',
#  'Zubat',
#  'Togepi',
#  'Noibat',
#  'Starly',
#  'Smeargle',
#  'Swinub',
#  'Spinarak',
#  'Slugma',
#  'Hoppip',
#  'Bidoof',
#  'Marill',
#  'Pidgey',
#  'Rattata',
#  'Patrat',
#  'Venipede',
#  'Wynaut',
#  'Skitty',
#  'Hoothoot',
#  'Spearow',
#  'Shinx',
#  'Pidove',
#  'Diglett',
#  'Ledyba',
#  'Nincada',
#  'Surskit',
#  'Taillow',
#  'Wingull',
#  'Jigglypuff',
#  'NidoranM',
#  'Lillipup',
#  'Litwick',
#  'Cherubi',
#  'NidoranF',
#  'Tynamo',
#  'Kirlia',
#  'Fletchling',
#  'Meditite',
#  'Petilil',
#  'Cottonee',
# ...

# %% [markdown]
# ## [] Rough idea of sampling based on total power hacked together
# 1. found gamma dist was similar to what i was looking for
# 2. made it so it would roughly cover the range of 800 pokemon
# 3. depending on which val was generated, appended that weak_to_strong[index] to found[]
# 4. did a count on allthe pokemon i found with counts
# 5. then tweaked the vals some more until i settled on ~30% chance for the really common ones, ~5% for the extreme ones

# %%
dfg = pd.DataFrame(np.random.gamma(3.5,100,800))
dfg.hist(bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2f98f884d0>]], dtype=object)

# %%
found = []
for i in range(10000):
    j = int(np.random.gamma(3.5,100)) # <--- was messed up for some reason so had to use int, floor didn't work
    #print(j)
    if j < len(weak_to_strong):
        #found[weak_to_strong[i]] += 1
        found.append(weak_to_strong[j])
        
found_df = pd.DataFrame(found)
found_pvals = found_df.apply(pd.value_counts)/100
#found_pvals.ix['Gloom']
found_pvals.plot()
